# %%
mkdir -p notebooks/audit/fsck/2026-02-08

# %%
dfs -get /media/notebooks/
# Out:
#   Cell In[8], line 1
#     dfs -get /media/notebooks/
#                               ^
# SyntaxError: invalid syntax

# %%
# !mount | grep notebooks
# Out:
# C:\ on /media/notebooks type 9p (rw,noatime,aname=drvfs;path=C:\;uid=0;gid=0;metadata;symlinkroot=/mnt/host/,cache=5,access=client,msize=65536,trans=fd,rfd=5,wfd=5)

# %%
# !ls /media/notebooks

# !ls /media/notebooks/2026-02-12
# Out:
# 2026-02-12  Untitled.ipynb
# fsck_data.txt  resumen.txt

# %%
# Para ver el directorio de trabajo actual del notebook
import os
print("Directorio actual:", os.getcwd())

# Para listar todo lo que hay en /media/notebooks
# !ls -l /media/notebooks
# Lista el contenido de la carpeta de la fecha
# !ls -l /media/notebooks/2026-02-12
# Out:
# Directorio actual: /media/notebooks
# total 4
# drwxrwxrwx 1 hdadmin hadoop 4096 Feb 12 20:08 2026-02-12
# -rwxrwxrwx 1 hdadmin hadoop 2305 Feb 12 20:40 Untitled.ipynb
# total 0
# -rwxrwxrwx 1 hdadmin hadoop   0 Feb 12 20:29 fsck_data.txt
# -rwxrwxrwx 1 hdadmin hadoop 143 Feb 12 20:29 resumen.txt

# %%
# !ls -l /media/notebooks
# Out:
# total 4
# drwxrwxrwx 1 hdadmin hadoop 4096 Feb 12 20:08 2026-02-12
# -rwxrwxrwx 1 hdadmin hadoop 2305 Feb 12 20:40 Untitled.ipynb
